# %% [markdown]
# # Public NYISO Power Market Data Analysis
#
# ## Project objective
#
# Develop a reproducible, public-data analysis of the relationship between NYISO market prices, load, and calendar conditions. The initial focus is zonal day-ahead LBMP and the difference between day-ahead and real-time prices.
#
# ## Public-data-only policy
#
# This is an independent personal educational project using only publicly available data, personal equipment, personal accounts, and personal time.
#
# This project does not use NYISO systems, nonpublic information, internal models, work product, confidential market information, or information obtained through employment.
#
# ## Initial hypothesis
#
# Public load, calendar variables, and historical price patterns explain a meaningful portion of variation in NYISO zonal day-ahead LBMP and day-ahead versus real-time price spreads. These variables may provide a useful benchmark before more advanced forecasting models are tested.
#
# ## Planned data sources
#
# - NYISO public day-ahead zonal LBMP data
# - NYISO public real-time zonal LBMP data
# - NYISO public actual load and load-forecast data
# - Public calendar and holiday variables
# - Public weather data, if added in a later phase

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests

print("Python environment is ready.")
print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# Python environment is ready.
# Pandas version: 3.0.5
# NumPy version: 2.5.2
